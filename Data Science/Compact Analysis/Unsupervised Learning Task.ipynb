# %% [markdown]
# # About the Data
# The data we'll be using comes from kaggle, and contains the following customer attributes:
#
# * ID
# * Age
# * Gender
# * Income
# * Spending score

# %% [markdown]
# # Problem Statement
#
# A business provides you with the following data and wants you to find patterns in their customer's habits so that they can make better recommendations and target certain groups in the future.
#
# ## *Answer the following*
#
# * **Would we approach this as a supervised or unsupervised learning task and why?**

# %% [markdown]
# ### Write your answer here:
# One would use an unsupervised learning task while conducting an analysis over this dataset. This can be seen in the data itself, seeing as to how letting the model work on it's own to produce patterns and clusters would be more beneficial and effective than any supervised learning task. Especially when referring to the problem statement, for grouping characteristics, unsupervised learning is the clear choice for this dataset analysis.

# %% [markdown]
# # Step 1
# ### Begin by importing the data and displaying the first 5 observations.

# %%
#Write your code here
from matplotlib import rcParams
rcParams['figure.figsize'] = 15, 5
import seaborn as sns
sns.set_style('darkgrid')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

customer_data = pd.read_csv("data.csv")
customer_data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ### Answer the following using Pandas:
# 1. How many observations are there in total?
# 2. Are there any missing values?
# 3. How many unique values are in each column?
# ### Write your answer here:
#
# There are a total of 5 observations in this dataset, with 4 unique values in each column. There are no missing values, as seen in the .head() function compared to the actual dataset description. This dataset is very optimal in terms of grouping and clustering; with this in mind, one should easily find an answer to our problem statement.

# %% [markdown]
# # Step 2
#
# ### Create the following plots:
# * A histogram of Age,
# * A histogram of Annual Income (k),
# * A histogram of Spending Score

# %%
#Write your code here
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
sns.distplot(customer_data['Age'], ax=axes[0])
axes[0].set_title('Age Distribution')
sns.distplot(customer_data['Annual Income (k$)'], ax=axes[1])
axes[1].set_title('Annual Income (k$) Distribution')
plt.show()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
sns.distplot(customer_data['Spending Score (1-100)'], ax=axes[0])
axes[0].set_title('Spending Score (1-100) Distribution')
plt.show()
# Out:
# C:\Users\morri\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\morri\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Answer the following:
# * What can you conclude from the histogram of Age? Are there any interesting findings?
# * What can you conclude from the histogram of Annual Income? Are there any interesting findings?
# * What can you conclude from the histogram of spending score? Are there any interesting findings?
#
# ### Write your answer here:
#
# Many conclusions can be made using the plots that were generated, especially when referring to the histogram of Age. One can see that the most frequent age of customers in this dataset are customers in their mid to late 30s, with the majority of overall customers being around 20-50 years old. One can also see that the most common Annual Income of customers would be between 50k-90k, with the highest concentration being from 50k-63k. Finally, one can see that the average spending score of customers in this dataset would be from 40-60, with 60 having a slightly higher concentration than that of 40.

# %% [markdown]
# ### Create a pie chart showing the proportions of male to female in our data.

# %%
sns.countplot(x=customer_data['Gender'], hue='Gender', data=customer_data)
plt.show()

# %% [markdown]
# ### Answer the following
# * What can you conclude from the plot you created?
#
# ### Write your answer here:
#
# After looking at the plot generated, one can see that on average, females shop slightly more than men in this dataset. This graph can give further insight into the demographics of certain stores, and can be used to help bolster certain products, seeing as to how females slightly tend to do more shopping than males.

# %% [markdown]
# ### Create a heatmap of the data.

# %%
#Write your code here
plt.figure(figsize = (25, 10))
sns.heatmap(customer_data.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ### Answer the following:
# * After creating your heatmap, is there anything interesting? For example, any significant multicollinearity?
#
# ### Write your answer here:
#
# After creating the heatmap, one can see that there is not much correlation between variables in this dataset, except for that of Annual Income and CustomerID. There is one case of significant multicollinearity in that of the correlation between Annual Income and CustomerID, having a score of 0.98. This score is much higher than that of 0.7, classifying it as a significant multicollinearity in this dataset. The only other correlation between variables would be between that of Spending Score and Annual Income.

# %% [markdown]
# ### Create the following plots:
# * A scatter plot of Age vs. Annual Income (k)
# * A scatter plot of Age vs. Spending
# * A scatter plot of Annual Income (k) vs. Spending Score (1-100)

# %%
#write your code here
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

sns.regplot(x='Age', y='Annual Income (k$)', data=customer_data, ax=axes[0][0], scatter_kws={'alpha':0.4})
axes[0][0].set_title('Age vs. Annual Income (k$)')

sns.regplot(x='Age', y='Spending Score (1-100)', data=customer_data, ax=axes[0][1], scatter_kws={'alpha':0.4})
axes[0][1].set_title('Age vs. Spending Score')

sns.regplot(x='Annual Income (k$)', y='Spending Score (1-100)', data=customer_data, ax=axes[1][0], scatter_kws={'alpha':0.4})
axes[1][0].set_title('Annual Income (k$) vs. Spending Score (1-100)')

plt.show()

# %% [markdown]
# ### Answer the following
# * What can you conclude from the first scatter plot you created? Are there any interesting findings?
# * What can you conclude from the second scatter plot you created? Are there any interesting findings?
# * What can you conclude from the thirs scatter plot you created? Are there any interesting findings?
#
# ### Write your answer here:
#
# Many conclusions can be made when referring to the plots created, especially when looking at the Age vs. Spending Score scatter plot. In this plot, one can see a negative relationship in that of age and spending score, meaning that the older a customer gets, the worse their spending score gets. One can also see that the relationship between Age vs. Annual Income is somewhat neutral, although slightly negative, with high concentrations of correlation from 30 to 40 years old. Finally, one can also see that the relationship between that of Annual Income vs. Spending Score is overall neutral, with very high concentrations of data from 40k to 70k annual incomes.

# %% [markdown]
# ### Create the follwing plot
# * A line graph of Annual Income (k) vs. Spending Score (1-100) for both genders.

# %%
#Write your code here
plt.plot(customer_data['Annual Income (k$)'], label='Annual Income (k)')
plt.plot(customer_data['Spending Score (1-100)'], label='Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# ### Answer the following:
# * What can you say about the plot you created?
#
# ### Write your answer here:
#
# When looking over the graph created, one can see that there is major overlap between the two variables: Annual Income and Spending Score. One can see that the majority of this overlap is between that of 40k-80k Annual Income and 25 to 60 years of age. With this in mind, one can conclude that the average customer in this dataset is from 25-60 years of age, with an annual income between that of 40k to 80k. Besides this finding, many other conclusions can be made surrounding the overlap of this graph, and the coinciding variables used.

# %% [markdown]
# # Step 3

# %% [markdown]
# ### k-means clustering
#
# ### For this step, perform the following:
# * Use the elbow method to find the optimal number of clusters.
# * Create a K-Means model using your optimal number of clusters
# * Visualize the clusters by plotting them (annual income on one axis and spending score on the other)

# %%
#Write your code here lab 10
X = customer_data.iloc[:, [2, 3,4]].values
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
sns.lineplot(x=range(1, 11), y=wcss,marker='o',color='red')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\morri\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_pred = kmeans.fit_predict(X)

# %%
sns.scatterplot(x=X[y_pred == 0, 0], y=X[y_pred == 0, 1], color = 'yellow', label = 'Cluster 1',s=50)
sns.scatterplot(x=X[y_pred == 1, 0], y=X[y_pred == 1, 1], color = 'blue', label = 'Cluster 2',s=50)
sns.scatterplot(x=X[y_pred == 2, 0], y=X[y_pred == 2, 1], color = 'green', label = 'Cluster 3',s=50)
sns.scatterplot(x=X[y_pred == 3, 0], y=X[y_pred == 3, 1], color = 'grey', label = 'Cluster 4',s=50)
sns.scatterplot(x=X[y_pred == 4, 0], y=X[y_pred == 4, 1], color = 'orange', label = 'Cluster 5',s=50)
sns.scatterplot(x=kmeans.cluster_centers_[:, 0], y=kmeans.cluster_centers_[:, 1], color = 'red',
                label = 'Centroids',s=100,marker=',')
plt.title('Clusters of Customers')
plt.xlabel('Age')
plt.ylabel('Annual Income')
plt.legend()
plt.show()

# %% [markdown]
# # Step 4
#
# ### Hierarchical Clustering
#
# * Create a Dendrogram to find the optimal number of clusters. Use method = 'ward'. Hint: Look at the old lab on hierarchical clustering or scipy.cluster.hierarchy
# * Visualizing the Clusters of hierarchical clustering

# %%
#Write your code here
from sklearn.preprocessing import StandardScaler, normalize

scaler = StandardScaler() 
scaled_df = scaler.fit_transform(customer_data.iloc[:, [2, 3,4]].values) 
  
normalized_df = normalize(scaled_df) 
normalized_df = pd.DataFrame(data=normalized_df)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2) 
X_principal = pca.fit_transform(normalized_df) 
X_principal = pd.DataFrame(X_principal) 
X_principal.columns = ['P1', 'P2'] 
  
X_principal.head()
# Out:
#          P1        P2
# 0 -0.358146 -0.808495
# 1 -0.634308 -0.729439
# 2 -0.030129 -0.656543
# 3 -0.594864 -0.763586
# 4 -0.067077 -0.936304

# %%
import scipy.cluster.hierarchy as shc

plt.title('visualising the data') 
Dendrogram = shc.dendrogram((shc.linkage(X_principal, method ='ward')))

# %%
from sklearn.cluster import AgglomerativeClustering 
from sklearn.metrics import silhouette_score
silhouette_scores = [] 
for n_cluster in range(2, 8):
    silhouette_scores.append(silhouette_score(X_principal,
                                              AgglomerativeClustering(n_clusters = n_cluster).fit_predict(X_principal))) 
agg = AgglomerativeClustering(n_clusters=3)
agg.fit(X_principal)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
plt.scatter(X_principal['P1'], X_principal['P2'],
            c = AgglomerativeClustering(n_clusters = 3).fit_predict(X_principal)) 
plt.show()

# %% [markdown]
# # Step 5
#
# ### Write a brief conclusion summarizing your results and how K-Means and Hierarchical clustering differed.

# %% [markdown]
# * Briefly explain how both k-means and hierarchical clustering work along with their advantages/disadvantages if any.

# %% [markdown]
# * Give an example of where you could use hierarchical clustering or k-means

# %% [markdown]
# ### Write your answer here:
#
#
# Being the most popular and simplest partitioning method for clustering, K-Means algorithm is a heuristic method where each cluster is represented by the center of the cluster; and the algorithm converges to stable centroids of clusters. Disadvantages of this algorithm would be that it is sensitive to outliers, that it is a lazy learner, and that you have to pre-specify the number of clusters (that being k). Hierarchical clustering is an algorithm used to group similar objects into clusters, where each cluster is distinct from another, although the insides of each cluster are similar to each other. The main advantage of this algorithm compared to that of K-Means would be that one would not have to re-specify the number of clusters. The main downside to this algorithm would be the heavy computational power needed to run it, seen in the large datasets this algorithm is primarily used with. An example of using hierarchical clustering or k-means algorithms can be seen in this very dataset analysis. In this analysis, one can see that the results of the hierarchical clustering were slightly more accurate than that of the k-means algorithm, as seen in the Agglomerative Clustering plot.  In all, one would use these algorithms in an unsupervised learning task, in order to group data and find an overall pattern in a dataset. With this in mind, after using both models to analyze the provided dataset, many conclusions can be made. One can conclude that businesses may want to target those that are around 25-60 years of age, make around 40k-80k dollars annually, and those that are female when creating advertisements, shelf placement theories, or any other tactics used when trying to improve overall sales. One can also conclude that businesses would want to aim towards younger customers, as seen in the negative relationship between age and spending scores of customers in this dataset; meaning that when a customer gets older, the worse their spending score gets. Overall, the findings of this dataset analysis can be of major influence to many businesses trying to bolster sales, giving major insight into the minds of customers around the world.
